# %% [markdown]
# ## Load results

# %%
import os.path
from Bio.Blast.Applications import NcbiblastxCommandline
import pandas as pd
import re
import pickle
import matplotlib.pyplot as plt
import numpy as np
#import soundex
from phonetisch import soundex
from auxilary_functions import *

# %% [markdown]
# ## Load non-marine and non-unknown species

# %%
#non_marine_df = pd.read_pickle('/home/erikz/data/agnes_pkl_files/filtered_without_unknown_and_marine.pkl') 
non_marine_df = pd.read_pickle('../../big_files/non_marine_but_marine_patents_no_unknowns.pkl')

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
freq_data_nm = non_marine_df.organism.value_counts()/float(sum(non_marine_df.organism.value_counts()))
freq_data_nm = pd.DataFrame({'marine_names':freq_data_nm.index, 'marine_freqs':freq_data_nm.values})
freq_data_nm['group'] = 0

# %%
freq_data_nm.sort_values(by=['marine_freqs'], ascending=False).head(50)
# Out:
#                      marine_names  marine_freqs  group
# 0            arabidopsis thaliana       0.08608      0
# 1                    homo sapiens       0.05703      0
# 2                        zea mays       0.05627      0
# 3                     glycine max       0.04818      0
# 4                    oryza sativa       0.03736      0
# 5     oryza sativa japonica group       0.03071      0
# 6                  brassica napus       0.02173      0
# 7        saccharomyces cerevisiae       0.01365      0
# 8                escherichia coli       0.01112      0
# 9               triticum aestivum       0.00951      0
# 10                   mus musculus       0.00828      0
# 11           solanum lycopersicum       0.00666      0
# 12                hordeum vulgare       0.00558      0
# 13            medicago truncatula       0.00507      0
# 14                    danio rerio       0.00464      0
# 15              nicotiana tabacum       0.00459      0
# ...

# %%
marine_df = pd.read_pickle('../data/soundex_marine_species.pkl')
marine_df['organism'] = marine_df['organism_x']
marine_df.drop(['organism_x', 'organism_y'], axis=1, inplace=True)
marine_df = marine_df[~marine_df.company.isnull()]

agnes_marine_df = pd.read_pickle('../data/filtered_marine_species.pkl') 
marine_df = marine_df[marine_df['organism'].isin(agnes_marine_df.organism)]
marine_df = filter_company_names(marine_df)

blasiak_marine = pd.read_csv('../data/processed/Blasiak-2018-filtered.csv', delimiter=',')
blasiak_marine = blasiak_marine[blasiak_marine['Included in this study? '] == 'YES']
marine_df = marine_df[marine_df['organism'].isin(blasiak_marine.Organism)]

# %%
freq_data_marine = marine_df.organism.value_counts()/float(sum(marine_df.organism.value_counts()))
freq_data_marine = pd.DataFrame({'marine_names':freq_data_marine.index, 'marine_freqs':freq_data_marine.values})
freq_data_marine['group'] = 1

# %%
#old_marine_df = pd.read_pickle('/home/erikz/data/mgr/data/filtered_and_annotated_marine_species_go_terms.pkl')

# %%
all_freq_data = pd.concat([freq_data_nm, freq_data_marine], ignore_index=True)

# %%
import seaborn as sns

# %%
all_freq_data = all_freq_data.sort_values(by=['marine_freqs'], ascending=False)

# %%
all_freq_data_test = all_freq_data.head(100)

# %%
all_freq_data_test = all_freq_data_test.sort_values(by=['group'], ascending=False)

# %%
all_freq_data_test.head(71)
# Out:
#                                marine_names  marine_freqs  group
# 8218                     ciona intestinalis       0.08755      1
# 8269                   bruguiera gymnorhiza       0.00420      1
# 8267                  pyrococcus horikoshii       0.00423      1
# 8266             synechococcus sp. pcc 7002       0.00430      1
# 8265                         schizochytrium       0.00433      1
# ...                                     ...           ...    ...
# 8243        uncultured marine bacterium 580       0.00829      1
# 8224  prochlorococcus marinus str. mit 9313       0.01924      1
# 8244             shewanella oneidensis mr-1       0.00824      1
# 8245                ruegeria pomeroyi dss-3       0.00696      1
# 8246                      aequorea victoria       0.00671      1
#
# [71 rows x 3 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

colors_array = np.array(['#5A69AF','#FC944A'])
colors_array = np.repeat(colors_array, [71, 29], axis=0)

numbers = all_freq_data_test.marine_freqs*100
numbers = numbers.round(decimals = 2)

browser_market_share = {
    'browsers': numbers.to_list(),
    'market_share': all_freq_data_test.marine_freqs.to_list(),
    'color': colors_array
}


class BubbleChart:
    def __init__(self, area, bubble_spacing=0):
        """
        Setup for bubble collapse.

        Parameters
        ----------
        area : array-like
            Area of the bubbles.
        bubble_spacing : float, default: 0
            Minimal spacing between bubbles after collapsing.

        Notes
        -----
        If "area" is sorted, the results might look weird.
        """
        area = np.asarray(area)
        r = np.sqrt(area / np.pi)

        self.bubble_spacing = bubble_spacing
        self.bubbles = np.ones((len(area), 4))
        self.bubbles[:, 2] = r
        self.bubbles[:, 3] = area
        self.maxstep = 2 * self.bubbles[:, 2].max() + self.bubble_spacing
        self.step_dist = self.maxstep / 2

        # calculate initial grid layout for bubbles
        length = np.ceil(np.sqrt(len(self.bubbles)))
        grid = np.arange(length) * self.maxstep
        gx, gy = np.meshgrid(grid, grid)
        self.bubbles[:, 0] = gx.flatten()[:len(self.bubbles)]
        self.bubbles[:, 1] = gy.flatten()[:len(self.bubbles)]

        self.com = self.center_of_mass()

    def center_of_mass(self):
        return np.average(
            self.bubbles[:, :2], axis=0, weights=self.bubbles[:, 3]
        )

    def center_distance(self, bubble, bubbles):
        return np.hypot(bubble[0] - bubbles[:, 0],
                        bubble[1] - bubbles[:, 1])

    def outline_distance(self, bubble, bubbles):
        center_distance = self.center_distance(bubble, bubbles)
        return center_distance - bubble[2] - \
            bubbles[:, 2] - self.bubble_spacing

    def check_collisions(self, bubble, bubbles):
        distance = self.outline_distance(bubble, bubbles)
        return len(distance[distance < 0])

    def collides_with(self, bubble, bubbles):
        distance = self.outline_distance(bubble, bubbles)
        idx_min = np.argmin(distance)
        return idx_min if type(idx_min) == np.ndarray else [idx_min]

    def collapse(self, n_iterations=50):
        """
        Move bubbles to the center of mass.

        Parameters
        ----------
        n_iterations : int, default: 50
            Number of moves to perform.
        """
        for _i in range(n_iterations):
            moves = 0
            for i in range(len(self.bubbles)):
                rest_bub = np.delete(self.bubbles, i, 0)
                # try to move directly towards the center of mass
                # direction vector from bubble to the center of mass
                dir_vec = self.com - self.bubbles[i, :2]

                # shorten direction vector to have length of 1
                dir_vec = dir_vec / np.sqrt(dir_vec.dot(dir_vec))

                # calculate new bubble position
                new_point = self.bubbles[i, :2] + dir_vec * self.step_dist
                new_bubble = np.append(new_point, self.bubbles[i, 2:4])

                # check whether new bubble collides with other bubbles
                if not self.check_collisions(new_bubble, rest_bub):
                    self.bubbles[i, :] = new_bubble
                    self.com = self.center_of_mass()
                    moves += 1
                else:
                    # try to move around a bubble that you collide with
                    # find colliding bubble
                    for colliding in self.collides_with(new_bubble, rest_bub):
                        # calculate direction vector
                        dir_vec = rest_bub[colliding, :2] - self.bubbles[i, :2]
                        dir_vec = dir_vec / np.sqrt(dir_vec.dot(dir_vec))
                        # calculate orthogonal vector
                        orth = np.array([dir_vec[1], -dir_vec[0]])
                        # test which direction to go
                        new_point1 = (self.bubbles[i, :2] + orth *
                                      self.step_dist)
                        new_point2 = (self.bubbles[i, :2] - orth *
                                      self.step_dist)
                        dist1 = self.center_distance(
                            self.com, np.array([new_point1]))
                        dist2 = self.center_distance(
                            self.com, np.array([new_point2]))
                        new_point = new_point1 if dist1 < dist2 else new_point2
                        new_bubble = np.append(new_point, self.bubbles[i, 2:4])
                        if not self.check_collisions(new_bubble, rest_bub):
                            self.bubbles[i, :] = new_bubble
                            self.com = self.center_of_mass()

            if moves / len(self.bubbles) < 0.1:
                self.step_dist = self.step_dist / 2

    def plot(self, ax, labels, colors):
        """
        Draw the bubble plot.

        Parameters
        ----------
        ax : matplotlib.axes.Axes
        labels : list
            Labels of the bubbles.
        colors : list
            Colors of the bubbles.
        """
        for i in range(len(self.bubbles)):
            circ = plt.Circle(
                self.bubbles[i, :2], self.bubbles[i, 2], color=colors[i])
            ax.add_patch(circ)
            ax.text(*self.bubbles[i, :2], labels[i],
                    horizontalalignment='center', verticalalignment='center')


bubble_chart = BubbleChart(area=browser_market_share['market_share'],
                           bubble_spacing=0.05)

bubble_chart.collapse()

fig, ax = plt.subplots(subplot_kw=dict(aspect="equal"), figsize=(15, 15))
bubble_chart.plot(
    ax, browser_market_share['browsers'], browser_market_share['color'])
ax.axis("off")
ax.relim()
ax.autoscale_view()
#ax.set_title('Browser market share')

plt.show()

# %%
all_freq_data_test[all_freq_data_test.group==1].sort_values(by=['marine_freqs'], ascending=False).head(60)
# Out:
#                                       marine_names  marine_freqs  group
# 8218                            ciona intestinalis       0.08755      1
# 8219                             synechococcus sp.       0.07537      1
# 8220                               vibrio cholerae       0.06611      1
# 8221                                  gadus morhua       0.05166      1
# 8222                          thraustochytrium sp.       0.02306      1
# 8223                             anguilla japonica       0.01976      1
# 8224         prochlorococcus marinus str. mit 9313       0.01924      1
# 8225                       prochlorococcus marinus       0.01542      1
# 8226                                   salmo salar       0.01427      1
# 8227                       vibrio parahaemolyticus       0.01400      1
# 8228                             vibrio vulnificus       0.01397      1
# 8229                           thermotoga maritima       0.01335      1
# ...

# %%
all_freq_data_test[all_freq_data_test.group==0].sort_values(by=['marine_freqs'], ascending=False)
# Out:
#                    marine_names  marine_freqs  group
# 0          arabidopsis thaliana       0.08608      0
# 1                  homo sapiens       0.05703      0
# 2                      zea mays       0.05627      0
# 3                   glycine max       0.04818      0
# 4                  oryza sativa       0.03736      0
# 5   oryza sativa japonica group       0.03071      0
# 6                brassica napus       0.02173      0
# 7      saccharomyces cerevisiae       0.01365      0
# 8              escherichia coli       0.01112      0
# 9             triticum aestivum       0.00951      0
# 10                 mus musculus       0.00828      0
# 11         solanum lycopersicum       0.00666      0
# 12              hordeum vulgare       0.00558      0
# 13          medicago truncatula       0.00507      0
# 14                  danio rerio       0.00464      0
# 15            nicotiana tabacum       0.00459      0
# 16            rattus norvegicus       0.00416      0
# ...
